# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Gang Xu**
#
# Data Scentist

# %% [markdown]
# *I am interested in data science because it can solve various problems*

# %% [markdown]
# ### The following code compute the average of given input

# %%
def my_avg(mylist):
    t_sum = 0
    for i in mylist: 
        t_sum+=i
    return t_sum/len(mylist)

t_list = [1,2,3]
my_avg(t_list)
# Out:
# 2.0

# %% [markdown]
# <hr>
# <ul>
#     <li>bulleted_one</li>
#     <li>bulleted_two</li>
#     <li>bulleted_three</li>
# </ul>
# <ol>
#     <li>bulleted_one</li>
#     <li>bulleted_two</li>
#     <li>bulleted_three</li>
# </ol>
#
# | product | prices |
# | --- | --- |
# | car | 8000 |
# | truck | 12000 |
# | tank | 10000 |
#
# [Google Search](https://www.google.com)
# ![alt text](https://tse2-mm.cn.bing.net/th/id/OIP-C.hs_Nl4nkva-ti7JXX_AMMAHaEo?w=286&h=180&c=7&r=0&o=5&pid=1.7 "Logo Title Text 1")
#
# ```python
# import numpy as np
# print('numpy is imported')
# ```
# > This is a blocked quote
#
# ~~This is a strikethrough~~
